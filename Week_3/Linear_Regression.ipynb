# %% [markdown]
# # Linear_Regression on Boston Housing Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
#Load data
df = pd.read_csv("HousingData.csv")
df.head()

# Data contains null spaces
df = df.dropna()

# %%
y = df['MEDV']
x = df.drop('MEDV', axis = 1)

x.shape, y.shape
# Out:
# ((394, 13), (394,))

# %%
# Splitting data into training and testing parts

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
print("training set size: ",  x_train.shape, y_train.shape)
print("Testing data size: ", x_test.shape, y_test.shape)
# Out:
# training set size:  (315, 13) (315,)
# Testing data size:  (79, 13) (79,)

# %%
# Linear regression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred.shape
# Out:
# (79,)

# %% [markdown]
# ### Plotting the Actual Result vs Predicted Result

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.plot([y.min(), y.max()],[y.min(), y.max()], color = "red")
plt.ylabel ("Predicted Price")
plt.xlabel("Actual Price")
plt.title("Predicted vs Actual Price Linear Regression")
plt.show()

# %% [markdown]
# ### Residual Plot

# %%
plt.scatter(y_pred, y_test - y_pred, alpha = 0.5)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted Values")
plt.show()

# %% [markdown]
# ### Model Evaluation

# %%
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
intercept = lr.intercept_

# Printing the values
print ("R2 Score: ", r2)   # variance
print("MSE: ", mse)
print("Mae: ", mae)
print("Intercept: " , intercept)


plt.show()
# Out:
# R2 Score:  0.627084994167318
# MSE:  31.454047664950963
# Mae:  3.367983225154248
# Intercept:  33.65240504056566
